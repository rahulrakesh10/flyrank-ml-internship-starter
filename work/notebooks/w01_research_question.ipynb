# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/flyrank-bih/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# For SEO specialists and content managers, deciding which ranking signals to prioritize for content improvement, we will perform signal analysis on Google Search anonymized data, measuring correlation strength and grouped effect sizes between ranking signals (clicks, impressions, engagement, content quality) and search position. A wrong prioritization costs wasted editorial effort on low-impact signals, reducing ROI on content optimization. A plain rule ("prioritize backlinks") isn't enough because signal impact is tangled—many signals move together, and their relative strength shifts by content type. We will claim only observed correlations and directional comparisons, never causal proof.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# The goal of this ranking signal analysis is to improve decisions about which factors should be prioritized to increase search rankings and online visibility. The primary users of these insights are SEO specialists, digital marketers, and content managers, who use the findings to optimize websites, create better content, and allocate marketing resources more effectively. A wrong recommendation can be costly, leading to wasted time and budget on ineffective strategies, reduced search visibility, lower website traffic, and missed opportunities to attract potential customers or achieve business goals.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv('../../data/raw/content_refresh_anonymized.csv')

# Show shape and date/metric range
print(f"Shape: {df.shape}")
print(f"\nColumns:\n{df.columns.tolist()}")
print(f"\nFirst 2 rows:\n{df.head(2)}")

# Example: show signal variance (CTR, engagement, position spread)
print(f"\nCTR stats (remember: ×100 = percentages):\n{df['ctr'].describe()}")
print(f"\nAvg position stats (0 = no data):\n{df['avg_position'].describe()}")
print(f"\nLabel balance:\n{df['trend_direction'].value_counts()}")
# Out:
# Shape: (30000, 44)
#
# Columns:
# ['content_id', 'client_id', 'search_volume', 'competition', 'competition_level', 'cpc', 'content_type', 'main_intent', 'word_count', 'char_count', 'provider_used', 'model_used', 'impressions_90d', 'clicks_90d', 'pageviews_90d', 'sessions_90d', 'users_90d', 'engaged_sessions_90d', 'ai_sessions_90d', 'scroll_events_90d', 'days_with_impressions', 'days_with_sessions', 'impressions_last_30d', 'clicks_last_30d', 'sessions_last_30d', 'impressions_prev_30d', 'clicks_prev_30d', 'sessions_prev_30d', 'content_age_days', 'age_tier', 'age_tier_order', 'days_since_last_update', 'freshness_tier', 'word_count_tier', 'char_count_tier', 'ctr', 'avg_position', 'engagement_rate', 'scroll_rate', 'ai_traffic_pct', 'impression_tier', 'position_tier', 'trend_direction', 'trend_pct']
#
# First 2 rows:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# This research will examine and analyze correlations observed among different ranking signals such as click, impression, engagement, backlink, and average search position to find out what signals have the highest correlation with better rankings. The results obtained from this study should help SEO professionals and content managers to optimize their activities on the basis of the revealed regularities in data. But it is important to note that this study will not prove that any ranking signal is the cause of better rankings and will not predict future changes in search rankings. It will just reveal correlations and directional trends found in the dataset.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
